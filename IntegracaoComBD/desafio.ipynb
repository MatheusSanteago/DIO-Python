# %% [markdown]
# SQLAlchemy

# %%
from sqlalchemy import Integer, String, Column, ForeignKey, create_engine, inspect, select, LargeBinary, Float
from sqlalchemy.orm import Session, declarative_base, relationship
from faker import Faker
import random

# %%
Base = declarative_base()

# %%
# Criando minhas tabelas, utilizando SQLAlchemy

class Client(Base):
    __tablename__ = 'bank_clients'

    id = Column(Integer, primary_key=True)
    name = Column(String)
    cpf = Column(String(9))
    address = Column(String(9))

    account = relationship('Account', back_populates='user',
                           cascade='all, delete-orphan')

    def __repr__(self):
        return f'Client(id={self.id}, name={self.name}, cpf={self.cpf}, address={self.address})'


class Account(Base):
    __tablename__ = 'bank_accounts'

    id = Column(Integer, primary_key=True, autoincrement=True)
    type = Column(String)
    agency = Column(String)
    num = Column(Integer)
    client_id = Column(Integer, ForeignKey('bank_clients.id'), nullable=False)
    balance = Column(Float)

    user = relationship('Client', back_populates='account')

    def __repr__(self):
        return f'Account(id={self.id}, type={self.type}, agency={self.agency}, client_id={self.client_id}, balance={self.balance})'

# %%
engine = create_engine('sqlite://')
Base.metadata.create_all(engine)

# %%
# Checando as tabelas do sqlite

isp = inspect(engine)
print(isp.get_table_names())
# Out:
# ['bank_accounts', 'bank_clients']

# %%
fake = Faker()

# Criando dados de maneira aleatória, para alimentar o banco de dados, utilizando Faker para os nomes e random para os números
with Session(engine) as session:
    accounts = []
    accounts_type = ['CC', 'CS']
    for i in range(1, 101):
        num = 0
        accounts.append(Account(type=accounts_type[random.randint(0, 1)], agency='0001', num=i, balance=random.randint(0, 10000),
                        user=Client(name=fake.name(), cpf=str(random.randint(100_000_000, 999_999_999)), address=str(random.randint(100_000_000, 999_999_999)))))

    session.add_all(accounts)
    session.commit()

# %%
conn = engine.connect()

# Realizando consulta utilizando join
stmt_join = select("*").join_from(Client, Account)
results = conn.execute(stmt_join).fetchall()

data = []
for i in results:
    data.append(list(i))

# %%
import pandas as pd

# Criando DataFrame com os dados vindo do SQLite
df_balance = pd.DataFrame(data, columns=[
                          'id_client', 'client', 'cpf', 'cep', 'account_id', 'acc_type', 'agency', 'num', 'client_id', 'balance'])
df = df_balance[['id_client', 'client', 'cpf',
                 'cep', 'acc_type', 'agency', 'num', 'balance']]

# %%
df.head()
# Out:
#    id_client          client        cpf        cep acc_type agency  num  \
# 0          1  Cathy Bautista  150489040  322332609       CC   0001    1
# 1          2     Jacob Smith  601982794  439811173       CC   0001    2
# 2          3  Jared Campbell  437239788  668129893       CS   0001    3
# 3          4      Ana Becker  258336363  134707812       CS   0001    4
# 4          5   Morgan Watson  250232242  849965633       CS   0001    5
#
#    balance
# 0   1279.0
# 1   2184.0
# 2   2639.0
# 3   1528.0
# 4   2042.0

# %% [markdown]
# Pymongo

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = ''

client = MongoClient(uri, server_api=ServerApi('1'))

# %%
# Conectando na collection

db = client.meubanco
meubanco = db.bank

# Loop com os dados fakes criados para alimentar o banco de dados SQL
for i in data:
    account = {
        'type': i[5],
        'agency': i[6],
        'num': i[7],
        'id_client': i[0],
        'balance': i[9],
        'client': {
            'id': i[0],
            'name': i[1],
            'cpf': i[2],
            'address': i[3]
        }
    }
    meubanco.insert_one(account)

# %%
# Realizar um print em todos os clientes com mias de 9000 na conta
for r in meubanco.find({'balance': {'$gt': 9000}}):
    print(r)
# Out:
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d4d'), 'type': 'CS', 'agency': '0001', 'num': 14, 'id_client': 14, 'balance': 9235.0, 'client': {'id': 14, 'name': 'Julia Andrews', 'cpf': '397864443', 'address': '836335875'}}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d53'), 'type': 'CC', 'agency': '0001', 'num': 20, 'id_client': 20, 'balance': 9779.0, 'client': {'id': 20, 'name': 'Julie Turner', 'cpf': '821571221', 'address': '471774216'}}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d62'), 'type': 'CC', 'agency': '0001', 'num': 35, 'id_client': 35, 'balance': 9744.0, 'client': {'id': 35, 'name': 'Michele Smith', 'cpf': '542275174', 'address': '637075996'}}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d63'), 'type': 'CS', 'agency': '0001', 'num': 36, 'id_client': 36, 'balance': 9617.0, 'client': {'id': 36, 'name': 'Nicole Compton', 'cpf': '269555265', 'address': '501142578'}}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d64'), 'type': 'CS', 'agency': '0001', 'num': 37, 'id_client': 37, 'balance': 9623.0, 'client': {'id': 37, 'name': 'Tara Perry', 'cpf': '509943000', 'address': '495100941'}}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d6b'), 'type': 'CS', 'agency': '0001', 'num': 44, 'id_client': 44, 'balance': 9548.0, 'client': {'id': 44, 'name': 'Sean Ray', 'cpf': '384282366', 'address': '919374576'}}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d7b'), 'type': 'CC', 'agency': '0001', 'num': 60, 'id_client': 60, 'balance': 9228.0, 'client': {'id': 60, 'name': 'Phillip Beasley', 'cpf': '129338440', 'address': '771540835'}}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d7f'), 'type': 'CC', 'agency': '0001', 'num': 64, 'id_client': 64, 'balance': 9300.0, 'client': {'id': 64, 'name': 'Frances Mcfarland', 'cpf': '592079224', 'address': '769947962'}}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d93'), 'type': 'CS', 'agency': '0001', 'num': 84, 'id_client': 84, 'balance': 9452.0, 'client': {'id': 84, 'name': 'Todd Lawrence', 'cpf': '223327957', 'address': '843498307'}}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d9b'), 'type': 'CS', 'agency': '0001', 'num': 92, 'id_client': 92, 'balance': 9620.0, 'client': {'id': 92, 'name': 'Bradley Robertson', 'cpf': '588016779', 'address': '578332627'}}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db2'), 'type': 'CS', 'agency': '0001', 'num': 12, 'id_client': 12, 'balance': 9254.0, 'client': {'id': 12, 'name': 'John Edwards', 'cpf': '960753186', 'address': '737250274'}}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db7'), 'type': 'CS', 'agency': '0001', 'num': 17, 'id_client': 17, 'balance': 9275.0, 'client': {'id': 17, 'name': 'Nathan Mcintyre', 'cpf': '116114648', 'address': '951070953'}}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dc8'), 'type': 'CS', 'agency': '0001', 'num': 34, 'id_client': 34, 'balance': 9891.0, 'client': {'id': 34, 'name': 'Brenda Bailey', 'cpf': '405252872', 'address': '911364646'}}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dc9'), 'type': 'CS', 'agency': '0001', 'num': 35, 'id_client': 35, 'balance': 9084.0, 'client': {'id': 35, 'name': 'Jessica Ford', 'cpf': '646290619', 'address': '930499589'}}
# {'_id': ObjectId('65ad9e97d0b20ffddd687ddf'), 'type': 'CS', 'agency': '0001', 'num': 57, 'id_client': 57, 'balance': 9254.0, 'client': {'id': 57, 'name': 'Patricia Beltran', 'cpf': '678799019', 'address': '238373716'}}
# {'_id': ObjectId('65ad9e98d0b20ffddd687de2'), 'type': 'CC', 'agency': '0001', 'num': 60, 'id_client': 60, 'balance': 9710.0, 'client': {'id': 60, 'name': 'Christina Rogers', 'cpf': '602049582', 'address': '824747065'}}
# {'_id': ObjectId('65ad9e98d0b20ffddd687de8'), 'type': 'CS', 'agency': '0001', 'num': 66, 'id_client': 66, 'balance': 9061.0, 'client': {'id': 66, 'name': 'Amber Rogers', 'cpf': '438258120', 'address': '390772547'}}
# {'_id': ObjectId('65ad9e98d0b20ffddd687df3'), 'type': 'CC', 'agency': '0001', 'num': 77, 'id_client': 77, 'balance': 9750.0, 'client': {'id': 77, 'name': 'Jessica Pena', 'cpf': '567946173', 'address': '714087283'}}
# {'_id': ObjectId('65ad9e98d0b20ffddd687dfb'), 'type': 'CC', 'agency': '0001', 'num': 85, 'id_client': 85, 'balance': 9188.0, 'client': {'id': 85, 'name': 'Alyssa Armstrong', 'cpf': '440130378', 'address': '867609036'}}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e02'), 'type': 'CS', 'agency': '0001', 'num': 92, 'id_client': 92, 'balance': 9938.0, 'client': {'id': 92, 'name': 'Joshua Shepard', 'cpf': '151004776', 'address': '145923867'}}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e09'), 'type': 'CC', 'agency': '0001', 'num': 99, 'id_client': 99, 'balance': 9390.0, 'client': {'id': 99, 'name': 'Laura Robinson', 'cpf': '717016336', 'address': '765673551'}}

# %%
# Todos os registros
for account in meubanco.find():
    pprint.pprint(account)
# Out:
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d40'),
#  'agency': '0001',
#  'balance': 1114.0,
#  'client': {'address': '300740199',
#             'cpf': '199868507',
#             'id': 1,
#             'name': 'Emily Moore'},
#  'id_client': 1,
#  'num': 1,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d41'),
#  'agency': '0001',
#  'balance': 2104.0,
#  'client': {'address': '258259829',
#             'cpf': '845046290',
#             'id': 2,
#             'name': 'William Davidson'},
#  'id_client': 2,
#  'num': 2,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d42'),
#  'agency': '0001',
#  'balance': 1534.0,
#  'client': {'address': '562996745',
#             'cpf': '830682787',
#             'id': 3,
#             'name': 'Breanna Jones'},
#  'id_client': 3,
#  'num': 3,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d43'),
#  'agency': '0001',
#  'balance': 4010.0,
#  'client': {'address': '765412392',
#             'cpf': '656026611',
#             'id': 4,
#             'name': 'Madison Simmons DVM'},
#  'id_client': 4,
#  'num': 4,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d44'),
#  'agency': '0001',
#  'balance': 3462.0,
#  'client': {'address': '395285620',
#             'cpf': '668524239',
#             'id': 5,
#             'name': 'Breanna Roberson'},
#  'id_client': 5,
#  'num': 5,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d45'),
#  'agency': '0001',
#  'balance': 339.0,
#  'client': {'address': '802017975',
#             'cpf': '783024199',
#             'id': 6,
#             'name': 'Patrick Castro'},
#  'id_client': 6,
#  'num': 6,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d46'),
#  'agency': '0001',
#  'balance': 1658.0,
#  'client': {'address': '619267045',
#             'cpf': '405227729',
#             'id': 7,
#             'name': 'Brittany Evans'},
#  'id_client': 7,
#  'num': 7,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d47'),
#  'agency': '0001',
#  'balance': 5070.0,
#  'client': {'address': '637711754',
#             'cpf': '931268319',
#             'id': 8,
#             'name': 'Bianca Alexander'},
#  'id_client': 8,
#  'num': 8,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d48'),
#  'agency': '0001',
#  'balance': 2436.0,
#  'client': {'address': '530743396',
#             'cpf': '470667654',
#             'id': 9,
#             'name': 'Lauren Ellis'},
#  'id_client': 9,
#  'num': 9,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d49'),
#  'agency': '0001',
#  'balance': 4738.0,
#  'client': {'address': '689291800',
#             'cpf': '320601260',
#             'id': 10,
#             'name': 'Alicia Bender'},
#  'id_client': 10,
#  'num': 10,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d4a'),
#  'agency': '0001',
#  'balance': 5189.0,
#  'client': {'address': '314591103',
#             'cpf': '344156633',
#             'id': 11,
#             'name': 'Brianna Gonzalez'},
#  'id_client': 11,
#  'num': 11,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d4b'),
#  'agency': '0001',
#  'balance': 8250.0,
#  'client': {'address': '490617126',
#             'cpf': '103559077',
#             'id': 12,
#             'name': 'Trevor Cochran'},
#  'id_client': 12,
#  'num': 12,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d4c'),
#  'agency': '0001',
#  'balance': 1908.0,
#  'client': {'address': '185511174',
#             'cpf': '751674226',
#             'id': 13,
#             'name': 'Brittany Johnson'},
#  'id_client': 13,
#  'num': 13,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d4d'),
#  'agency': '0001',
#  'balance': 9235.0,
#  'client': {'address': '836335875',
#             'cpf': '397864443',
#             'id': 14,
#             'name': 'Julia Andrews'},
#  'id_client': 14,
#  'num': 14,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1cd0b20ffddd687d4e'),
#  'agency': '0001',
#  'balance': 6886.0,
#  'client': {'address': '362621051',
#             'cpf': '548525579',
#             'id': 15,
#             'name': 'Zachary Garrison'},
#  'id_client': 15,
#  'num': 15,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d4f'),
#  'agency': '0001',
#  'balance': 2580.0,
#  'client': {'address': '623419810',
#             'cpf': '799140596',
#             'id': 16,
#             'name': 'Michael House'},
#  'id_client': 16,
#  'num': 16,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d50'),
#  'agency': '0001',
#  'balance': 7485.0,
#  'client': {'address': '608556589',
#             'cpf': '204265113',
#             'id': 17,
#             'name': 'Michaela Wallace'},
#  'id_client': 17,
#  'num': 17,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d51'),
#  'agency': '0001',
#  'balance': 2508.0,
#  'client': {'address': '477370322',
#             'cpf': '887613964',
#             'id': 18,
#             'name': 'Maureen Williams'},
#  'id_client': 18,
#  'num': 18,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d52'),
#  'agency': '0001',
#  'balance': 78.0,
#  'client': {'address': '110894906',
#             'cpf': '979451352',
#             'id': 19,
#             'name': 'Ryan Stewart'},
#  'id_client': 19,
#  'num': 19,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d53'),
#  'agency': '0001',
#  'balance': 9779.0,
#  'client': {'address': '471774216',
#             'cpf': '821571221',
#             'id': 20,
#             'name': 'Julie Turner'},
#  'id_client': 20,
#  'num': 20,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d54'),
#  'agency': '0001',
#  'balance': 3312.0,
#  'client': {'address': '641201145',
#             'cpf': '391962324',
#             'id': 21,
#             'name': 'Ashley Barron'},
#  'id_client': 21,
#  'num': 21,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d55'),
#  'agency': '0001',
#  'balance': 7026.0,
#  'client': {'address': '540450682',
#             'cpf': '634707152',
#             'id': 22,
#             'name': 'Joel Edwards'},
#  'id_client': 22,
#  'num': 22,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d56'),
#  'agency': '0001',
#  'balance': 926.0,
#  'client': {'address': '415929099',
#             'cpf': '665311048',
#             'id': 23,
#             'name': 'William Padilla'},
#  'id_client': 23,
#  'num': 23,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d57'),
#  'agency': '0001',
#  'balance': 3264.0,
#  'client': {'address': '263772565',
#             'cpf': '359879384',
#             'id': 24,
#             'name': 'Jessica Harmon'},
#  'id_client': 24,
#  'num': 24,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d58'),
#  'agency': '0001',
#  'balance': 2823.0,
#  'client': {'address': '266631129',
#             'cpf': '122542731',
#             'id': 25,
#             'name': 'Laurie Jones'},
#  'id_client': 25,
#  'num': 25,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d59'),
#  'agency': '0001',
#  'balance': 4225.0,
#  'client': {'address': '151137557',
#             'cpf': '274709371',
#             'id': 26,
#             'name': 'Teresa Mckinney'},
#  'id_client': 26,
#  'num': 26,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d5a'),
#  'agency': '0001',
#  'balance': 7280.0,
#  'client': {'address': '913772580',
#             'cpf': '615735412',
#             'id': 27,
#             'name': 'Kayla Harris'},
#  'id_client': 27,
#  'num': 27,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d5b'),
#  'agency': '0001',
#  'balance': 6235.0,
#  'client': {'address': '190595455',
#             'cpf': '371320863',
#             'id': 28,
#             'name': 'Jesse Mendoza'},
#  'id_client': 28,
#  'num': 28,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d5c'),
#  'agency': '0001',
#  'balance': 7754.0,
#  'client': {'address': '343392816',
#             'cpf': '859528103',
#             'id': 29,
#             'name': 'Patrick Mahoney'},
#  'id_client': 29,
#  'num': 29,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d5d'),
#  'agency': '0001',
#  'balance': 4953.0,
#  'client': {'address': '755898443',
#             'cpf': '929529011',
#             'id': 30,
#             'name': 'Thomas Anderson'},
#  'id_client': 30,
#  'num': 30,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d5e'),
#  'agency': '0001',
#  'balance': 7059.0,
#  'client': {'address': '222340278',
#             'cpf': '121828269',
#             'id': 31,
#             'name': 'Jacqueline Sosa'},
#  'id_client': 31,
#  'num': 31,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d5f'),
#  'agency': '0001',
#  'balance': 1649.0,
#  'client': {'address': '524888636',
#             'cpf': '137556687',
#             'id': 32,
#             'name': 'Scott Smith'},
#  'id_client': 32,
#  'num': 32,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d60'),
#  'agency': '0001',
#  'balance': 1188.0,
#  'client': {'address': '742283230',
#             'cpf': '582263733',
#             'id': 33,
#             'name': 'Mrs. Kelly Johnson'},
#  'id_client': 33,
#  'num': 33,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d61'),
#  'agency': '0001',
#  'balance': 8351.0,
#  'client': {'address': '272167904',
#             'cpf': '558325402',
#             'id': 34,
#             'name': 'Anthony Castro'},
#  'id_client': 34,
#  'num': 34,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d62'),
#  'agency': '0001',
#  'balance': 9744.0,
#  'client': {'address': '637075996',
#             'cpf': '542275174',
#             'id': 35,
#             'name': 'Michele Smith'},
#  'id_client': 35,
#  'num': 35,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d63'),
#  'agency': '0001',
#  'balance': 9617.0,
#  'client': {'address': '501142578',
#             'cpf': '269555265',
#             'id': 36,
#             'name': 'Nicole Compton'},
#  'id_client': 36,
#  'num': 36,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d64'),
#  'agency': '0001',
#  'balance': 9623.0,
#  'client': {'address': '495100941',
#             'cpf': '509943000',
#             'id': 37,
#             'name': 'Tara Perry'},
#  'id_client': 37,
#  'num': 37,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d65'),
#  'agency': '0001',
#  'balance': 4231.0,
#  'client': {'address': '435915388',
#             'cpf': '729380566',
#             'id': 38,
#             'name': 'Melanie White'},
#  'id_client': 38,
#  'num': 38,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d66'),
#  'agency': '0001',
#  'balance': 2122.0,
#  'client': {'address': '991290751',
#             'cpf': '722416987',
#             'id': 39,
#             'name': 'Matthew Daniel'},
#  'id_client': 39,
#  'num': 39,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d67'),
#  'agency': '0001',
#  'balance': 4160.0,
#  'client': {'address': '415415560',
#             'cpf': '200337245',
#             'id': 40,
#             'name': 'Lisa Johnson'},
#  'id_client': 40,
#  'num': 40,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d68'),
#  'agency': '0001',
#  'balance': 8414.0,
#  'client': {'address': '493516877',
#             'cpf': '710876548',
#             'id': 41,
#             'name': 'Rebecca James'},
#  'id_client': 41,
#  'num': 41,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d69'),
#  'agency': '0001',
#  'balance': 5742.0,
#  'client': {'address': '930008743',
#             'cpf': '736397650',
#             'id': 42,
#             'name': 'Diana Casey'},
#  'id_client': 42,
#  'num': 42,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d6a'),
#  'agency': '0001',
#  'balance': 543.0,
#  'client': {'address': '852692118',
#             'cpf': '535721681',
#             'id': 43,
#             'name': 'Robert Flores'},
#  'id_client': 43,
#  'num': 43,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d6b'),
#  'agency': '0001',
#  'balance': 9548.0,
#  'client': {'address': '919374576',
#             'cpf': '384282366',
#             'id': 44,
#             'name': 'Sean Ray'},
#  'id_client': 44,
#  'num': 44,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d6c'),
#  'agency': '0001',
#  'balance': 954.0,
#  'client': {'address': '258301494',
#             'cpf': '274182219',
#             'id': 45,
#             'name': 'Jennifer Johnson'},
#  'id_client': 45,
#  'num': 45,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d6d'),
#  'agency': '0001',
#  'balance': 3797.0,
#  'client': {'address': '162924502',
#             'cpf': '267044772',
#             'id': 46,
#             'name': 'Jeffery Beck'},
#  'id_client': 46,
#  'num': 46,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1dd0b20ffddd687d6e'),
#  'agency': '0001',
#  'balance': 6405.0,
#  'client': {'address': '993294653',
#             'cpf': '862807576',
#             'id': 47,
#             'name': 'David Roach'},
#  'id_client': 47,
#  'num': 47,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d6f'),
#  'agency': '0001',
#  'balance': 3080.0,
#  'client': {'address': '955608578',
#             'cpf': '874285966',
#             'id': 48,
#             'name': 'Amy Dean'},
#  'id_client': 48,
#  'num': 48,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d70'),
#  'agency': '0001',
#  'balance': 532.0,
#  'client': {'address': '886156754',
#             'cpf': '752511212',
#             'id': 49,
#             'name': 'Crystal Elliott'},
#  'id_client': 49,
#  'num': 49,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d71'),
#  'agency': '0001',
#  'balance': 5277.0,
#  'client': {'address': '307461118',
#             'cpf': '356529897',
#             'id': 50,
#             'name': 'James Green'},
#  'id_client': 50,
#  'num': 50,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d72'),
#  'agency': '0001',
#  'balance': 794.0,
#  'client': {'address': '425464074',
#             'cpf': '827521702',
#             'id': 51,
#             'name': 'Donald Carrillo'},
#  'id_client': 51,
#  'num': 51,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d73'),
#  'agency': '0001',
#  'balance': 5850.0,
#  'client': {'address': '580731938',
#             'cpf': '153605273',
#             'id': 52,
#             'name': 'Michele Coleman'},
#  'id_client': 52,
#  'num': 52,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d74'),
#  'agency': '0001',
#  'balance': 4556.0,
#  'client': {'address': '319053251',
#             'cpf': '195595415',
#             'id': 53,
#             'name': 'Joseph Vega'},
#  'id_client': 53,
#  'num': 53,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d75'),
#  'agency': '0001',
#  'balance': 4217.0,
#  'client': {'address': '787434050',
#             'cpf': '860561787',
#             'id': 54,
#             'name': 'Theresa Cook'},
#  'id_client': 54,
#  'num': 54,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d76'),
#  'agency': '0001',
#  'balance': 356.0,
#  'client': {'address': '411906116',
#             'cpf': '581576176',
#             'id': 55,
#             'name': 'Mary Richardson'},
#  'id_client': 55,
#  'num': 55,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d77'),
#  'agency': '0001',
#  'balance': 942.0,
#  'client': {'address': '886632870',
#             'cpf': '862166081',
#             'id': 56,
#             'name': 'Anthony Paul'},
#  'id_client': 56,
#  'num': 56,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d78'),
#  'agency': '0001',
#  'balance': 5210.0,
#  'client': {'address': '388542164',
#             'cpf': '757417194',
#             'id': 57,
#             'name': 'Thomas Baldwin'},
#  'id_client': 57,
#  'num': 57,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d79'),
#  'agency': '0001',
#  'balance': 8200.0,
#  'client': {'address': '637747651',
#             'cpf': '669067165',
#             'id': 58,
#             'name': 'Eric Terry'},
#  'id_client': 58,
#  'num': 58,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d7a'),
#  'agency': '0001',
#  'balance': 3390.0,
#  'client': {'address': '876080049',
#             'cpf': '577685286',
#             'id': 59,
#             'name': 'Kelly Gamble'},
#  'id_client': 59,
#  'num': 59,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d7b'),
#  'agency': '0001',
#  'balance': 9228.0,
#  'client': {'address': '771540835',
#             'cpf': '129338440',
#             'id': 60,
#             'name': 'Phillip Beasley'},
#  'id_client': 60,
#  'num': 60,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d7c'),
#  'agency': '0001',
#  'balance': 7995.0,
#  'client': {'address': '376034771',
#             'cpf': '269996236',
#             'id': 61,
#             'name': 'Emily Hoffman'},
#  'id_client': 61,
#  'num': 61,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d7d'),
#  'agency': '0001',
#  'balance': 8846.0,
#  'client': {'address': '885010496',
#             'cpf': '720113809',
#             'id': 62,
#             'name': 'Jose Duncan'},
#  'id_client': 62,
#  'num': 62,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d7e'),
#  'agency': '0001',
#  'balance': 8698.0,
#  'client': {'address': '395346205',
#             'cpf': '120111967',
#             'id': 63,
#             'name': 'Morgan Dunn'},
#  'id_client': 63,
#  'num': 63,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d7f'),
#  'agency': '0001',
#  'balance': 9300.0,
#  'client': {'address': '769947962',
#             'cpf': '592079224',
#             'id': 64,
#             'name': 'Frances Mcfarland'},
#  'id_client': 64,
#  'num': 64,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d80'),
#  'agency': '0001',
#  'balance': 2104.0,
#  'client': {'address': '370049545',
#             'cpf': '593296953',
#             'id': 65,
#             'name': 'Lori Smith'},
#  'id_client': 65,
#  'num': 65,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d81'),
#  'agency': '0001',
#  'balance': 3872.0,
#  'client': {'address': '435287616',
#             'cpf': '851700748',
#             'id': 66,
#             'name': 'Elizabeth Johnson'},
#  'id_client': 66,
#  'num': 66,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d82'),
#  'agency': '0001',
#  'balance': 371.0,
#  'client': {'address': '725243487',
#             'cpf': '374116207',
#             'id': 67,
#             'name': 'Brian Thompson'},
#  'id_client': 67,
#  'num': 67,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d83'),
#  'agency': '0001',
#  'balance': 3240.0,
#  'client': {'address': '554613393',
#             'cpf': '275786107',
#             'id': 68,
#             'name': 'Sierra Morales'},
#  'id_client': 68,
#  'num': 68,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d84'),
#  'agency': '0001',
#  'balance': 7866.0,
#  'client': {'address': '612961567',
#             'cpf': '824346409',
#             'id': 69,
#             'name': 'Brian Page'},
#  'id_client': 69,
#  'num': 69,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d85'),
#  'agency': '0001',
#  'balance': 2885.0,
#  'client': {'address': '315177937',
#             'cpf': '520979035',
#             'id': 70,
#             'name': 'Gerald Lopez'},
#  'id_client': 70,
#  'num': 70,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d86'),
#  'agency': '0001',
#  'balance': 262.0,
#  'client': {'address': '154752559',
#             'cpf': '442900884',
#             'id': 71,
#             'name': 'Christopher Harrison'},
#  'id_client': 71,
#  'num': 71,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d87'),
#  'agency': '0001',
#  'balance': 4337.0,
#  'client': {'address': '467830906',
#             'cpf': '931094222',
#             'id': 72,
#             'name': 'George Gibson'},
#  'id_client': 72,
#  'num': 72,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d88'),
#  'agency': '0001',
#  'balance': 679.0,
#  'client': {'address': '644675379',
#             'cpf': '434164782',
#             'id': 73,
#             'name': 'Nicholas Martinez'},
#  'id_client': 73,
#  'num': 73,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d89'),
#  'agency': '0001',
#  'balance': 196.0,
#  'client': {'address': '999702917',
#             'cpf': '838717592',
#             'id': 74,
#             'name': 'Timothy Williams MD'},
#  'id_client': 74,
#  'num': 74,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d8a'),
#  'agency': '0001',
#  'balance': 4385.0,
#  'client': {'address': '359229509',
#             'cpf': '656430842',
#             'id': 75,
#             'name': 'Daniel Robinson'},
#  'id_client': 75,
#  'num': 75,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d8b'),
#  'agency': '0001',
#  'balance': 3248.0,
#  'client': {'address': '884580222',
#             'cpf': '660993142',
#             'id': 76,
#             'name': 'Candice Smith'},
#  'id_client': 76,
#  'num': 76,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d8c'),
#  'agency': '0001',
#  'balance': 7268.0,
#  'client': {'address': '712048901',
#             'cpf': '710257864',
#             'id': 77,
#             'name': 'Justin Bullock'},
#  'id_client': 77,
#  'num': 77,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d8d'),
#  'agency': '0001',
#  'balance': 3231.0,
#  'client': {'address': '230966293',
#             'cpf': '845966284',
#             'id': 78,
#             'name': 'Lisa Schaefer'},
#  'id_client': 78,
#  'num': 78,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d8e'),
#  'agency': '0001',
#  'balance': 4201.0,
#  'client': {'address': '692162751',
#             'cpf': '312066707',
#             'id': 79,
#             'name': 'Sherry Lamb'},
#  'id_client': 79,
#  'num': 79,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1ed0b20ffddd687d8f'),
#  'agency': '0001',
#  'balance': 7892.0,
#  'client': {'address': '937504103',
#             'cpf': '554334157',
#             'id': 80,
#             'name': 'Larry Steele'},
#  'id_client': 80,
#  'num': 80,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d90'),
#  'agency': '0001',
#  'balance': 3012.0,
#  'client': {'address': '894512215',
#             'cpf': '656748487',
#             'id': 81,
#             'name': 'James Howard'},
#  'id_client': 81,
#  'num': 81,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d91'),
#  'agency': '0001',
#  'balance': 1550.0,
#  'client': {'address': '885344289',
#             'cpf': '549123757',
#             'id': 82,
#             'name': 'Susan Fields'},
#  'id_client': 82,
#  'num': 82,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d92'),
#  'agency': '0001',
#  'balance': 5020.0,
#  'client': {'address': '993297070',
#             'cpf': '604287572',
#             'id': 83,
#             'name': 'Francis Washington'},
#  'id_client': 83,
#  'num': 83,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d93'),
#  'agency': '0001',
#  'balance': 9452.0,
#  'client': {'address': '843498307',
#             'cpf': '223327957',
#             'id': 84,
#             'name': 'Todd Lawrence'},
#  'id_client': 84,
#  'num': 84,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d94'),
#  'agency': '0001',
#  'balance': 5648.0,
#  'client': {'address': '568471164',
#             'cpf': '323074716',
#             'id': 85,
#             'name': 'Gregory Harris'},
#  'id_client': 85,
#  'num': 85,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d95'),
#  'agency': '0001',
#  'balance': 6388.0,
#  'client': {'address': '299716401',
#             'cpf': '884021042',
#             'id': 86,
#             'name': 'Karen Shah'},
#  'id_client': 86,
#  'num': 86,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d96'),
#  'agency': '0001',
#  'balance': 5955.0,
#  'client': {'address': '911446655',
#             'cpf': '426597947',
#             'id': 87,
#             'name': 'David Lucas'},
#  'id_client': 87,
#  'num': 87,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d97'),
#  'agency': '0001',
#  'balance': 4436.0,
#  'client': {'address': '940373629',
#             'cpf': '873313766',
#             'id': 88,
#             'name': 'Kim Martinez'},
#  'id_client': 88,
#  'num': 88,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d98'),
#  'agency': '0001',
#  'balance': 5927.0,
#  'client': {'address': '927943049',
#             'cpf': '552428379',
#             'id': 89,
#             'name': 'Samuel Rogers'},
#  'id_client': 89,
#  'num': 89,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d99'),
#  'agency': '0001',
#  'balance': 3211.0,
#  'client': {'address': '404851940',
#             'cpf': '515556602',
#             'id': 90,
#             'name': 'John James'},
#  'id_client': 90,
#  'num': 90,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d9a'),
#  'agency': '0001',
#  'balance': 505.0,
#  'client': {'address': '863718184',
#             'cpf': '121488593',
#             'id': 91,
#             'name': 'Justin Garcia'},
#  'id_client': 91,
#  'num': 91,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d9b'),
#  'agency': '0001',
#  'balance': 9620.0,
#  'client': {'address': '578332627',
#             'cpf': '588016779',
#             'id': 92,
#             'name': 'Bradley Robertson'},
#  'id_client': 92,
#  'num': 92,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d9c'),
#  'agency': '0001',
#  'balance': 2967.0,
#  'client': {'address': '721868886',
#             'cpf': '566305276',
#             'id': 93,
#             'name': 'Kyle Bird'},
#  'id_client': 93,
#  'num': 93,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d9d'),
#  'agency': '0001',
#  'balance': 6759.0,
#  'client': {'address': '422849350',
#             'cpf': '113621077',
#             'id': 94,
#             'name': 'Jason Holland'},
#  'id_client': 94,
#  'num': 94,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d9e'),
#  'agency': '0001',
#  'balance': 3042.0,
#  'client': {'address': '975013070',
#             'cpf': '555265295',
#             'id': 95,
#             'name': 'Michael Murray'},
#  'id_client': 95,
#  'num': 95,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687d9f'),
#  'agency': '0001',
#  'balance': 412.0,
#  'client': {'address': '199524814',
#             'cpf': '111400812',
#             'id': 96,
#             'name': 'Anna Ross'},
#  'id_client': 96,
#  'num': 96,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687da0'),
#  'agency': '0001',
#  'balance': 7446.0,
#  'client': {'address': '657903731',
#             'cpf': '411888544',
#             'id': 97,
#             'name': 'Jesus Mills'},
#  'id_client': 97,
#  'num': 97,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687da1'),
#  'agency': '0001',
#  'balance': 8511.0,
#  'client': {'address': '991416628',
#             'cpf': '745409328',
#             'id': 98,
#             'name': 'Jeffrey Hill'},
#  'id_client': 98,
#  'num': 98,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687da2'),
#  'agency': '0001',
#  'balance': 3091.0,
#  'client': {'address': '799795661',
#             'cpf': '877354602',
#             'id': 99,
#             'name': 'Martin Smith'},
#  'id_client': 99,
#  'num': 99,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9b1fd0b20ffddd687da3'),
#  'agency': '0001',
#  'balance': 521.0,
#  'client': {'address': '100524327',
#             'cpf': '222064818',
#             'id': 100,
#             'name': 'Matthew Mcdonald'},
#  'id_client': 100,
#  'num': 100,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e95d0b20ffddd687da7'),
#  'agency': '0001',
#  'balance': 1279.0,
#  'client': {'address': '322332609',
#             'cpf': '150489040',
#             'id': 1,
#             'name': 'Cathy Bautista'},
#  'id_client': 1,
#  'num': 1,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687da8'),
#  'agency': '0001',
#  'balance': 2184.0,
#  'client': {'address': '439811173',
#             'cpf': '601982794',
#             'id': 2,
#             'name': 'Jacob Smith'},
#  'id_client': 2,
#  'num': 2,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687da9'),
#  'agency': '0001',
#  'balance': 2639.0,
#  'client': {'address': '668129893',
#             'cpf': '437239788',
#             'id': 3,
#             'name': 'Jared Campbell'},
#  'id_client': 3,
#  'num': 3,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687daa'),
#  'agency': '0001',
#  'balance': 1528.0,
#  'client': {'address': '134707812',
#             'cpf': '258336363',
#             'id': 4,
#             'name': 'Ana Becker'},
#  'id_client': 4,
#  'num': 4,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dab'),
#  'agency': '0001',
#  'balance': 2042.0,
#  'client': {'address': '849965633',
#             'cpf': '250232242',
#             'id': 5,
#             'name': 'Morgan Watson'},
#  'id_client': 5,
#  'num': 5,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dac'),
#  'agency': '0001',
#  'balance': 6731.0,
#  'client': {'address': '792244454',
#             'cpf': '221331337',
#             'id': 6,
#             'name': 'Margaret Rodriguez'},
#  'id_client': 6,
#  'num': 6,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dad'),
#  'agency': '0001',
#  'balance': 8456.0,
#  'client': {'address': '497453216',
#             'cpf': '113762118',
#             'id': 7,
#             'name': 'Joyce Fowler'},
#  'id_client': 7,
#  'num': 7,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dae'),
#  'agency': '0001',
#  'balance': 4343.0,
#  'client': {'address': '523016447',
#             'cpf': '606211508',
#             'id': 8,
#             'name': 'April Rodriguez'},
#  'id_client': 8,
#  'num': 8,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687daf'),
#  'agency': '0001',
#  'balance': 5862.0,
#  'client': {'address': '677795063',
#             'cpf': '891026483',
#             'id': 9,
#             'name': 'Jose Sutton'},
#  'id_client': 9,
#  'num': 9,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db0'),
#  'agency': '0001',
#  'balance': 1571.0,
#  'client': {'address': '146090704',
#             'cpf': '311983383',
#             'id': 10,
#             'name': 'Haley Meyers'},
#  'id_client': 10,
#  'num': 10,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db1'),
#  'agency': '0001',
#  'balance': 419.0,
#  'client': {'address': '587078712',
#             'cpf': '664823286',
#             'id': 11,
#             'name': 'Ronald Davis'},
#  'id_client': 11,
#  'num': 11,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db2'),
#  'agency': '0001',
#  'balance': 9254.0,
#  'client': {'address': '737250274',
#             'cpf': '960753186',
#             'id': 12,
#             'name': 'John Edwards'},
#  'id_client': 12,
#  'num': 12,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db3'),
#  'agency': '0001',
#  'balance': 5465.0,
#  'client': {'address': '869481196',
#             'cpf': '495805978',
#             'id': 13,
#             'name': 'Noah Powell'},
#  'id_client': 13,
#  'num': 13,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db4'),
#  'agency': '0001',
#  'balance': 7600.0,
#  'client': {'address': '171830759',
#             'cpf': '192769386',
#             'id': 14,
#             'name': 'Cassidy Jackson'},
#  'id_client': 14,
#  'num': 14,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db5'),
#  'agency': '0001',
#  'balance': 5768.0,
#  'client': {'address': '381444660',
#             'cpf': '948419407',
#             'id': 15,
#             'name': 'Sharon Stewart'},
#  'id_client': 15,
#  'num': 15,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db6'),
#  'agency': '0001',
#  'balance': 4828.0,
#  'client': {'address': '687196594',
#             'cpf': '664319170',
#             'id': 16,
#             'name': 'Karen Bolton'},
#  'id_client': 16,
#  'num': 16,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db7'),
#  'agency': '0001',
#  'balance': 9275.0,
#  'client': {'address': '951070953',
#             'cpf': '116114648',
#             'id': 17,
#             'name': 'Nathan Mcintyre'},
#  'id_client': 17,
#  'num': 17,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db8'),
#  'agency': '0001',
#  'balance': 1334.0,
#  'client': {'address': '950599493',
#             'cpf': '315756963',
#             'id': 18,
#             'name': 'Heather Webb'},
#  'id_client': 18,
#  'num': 18,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687db9'),
#  'agency': '0001',
#  'balance': 8001.0,
#  'client': {'address': '565731002',
#             'cpf': '213073198',
#             'id': 19,
#             'name': 'Pamela Beck'},
#  'id_client': 19,
#  'num': 19,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dba'),
#  'agency': '0001',
#  'balance': 244.0,
#  'client': {'address': '768763980',
#             'cpf': '397974558',
#             'id': 20,
#             'name': 'Deborah Thompson'},
#  'id_client': 20,
#  'num': 20,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dbb'),
#  'agency': '0001',
#  'balance': 7903.0,
#  'client': {'address': '994408286',
#             'cpf': '548719345',
#             'id': 21,
#             'name': 'Jean Jackson'},
#  'id_client': 21,
#  'num': 21,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dbc'),
#  'agency': '0001',
#  'balance': 4274.0,
#  'client': {'address': '273078985',
#             'cpf': '783511978',
#             'id': 22,
#             'name': 'John Davis'},
#  'id_client': 22,
#  'num': 22,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dbd'),
#  'agency': '0001',
#  'balance': 777.0,
#  'client': {'address': '405181441',
#             'cpf': '258326992',
#             'id': 23,
#             'name': 'James Gonzalez'},
#  'id_client': 23,
#  'num': 23,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dbe'),
#  'agency': '0001',
#  'balance': 1769.0,
#  'client': {'address': '452274540',
#             'cpf': '970169190',
#             'id': 24,
#             'name': 'James Harrison'},
#  'id_client': 24,
#  'num': 24,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dbf'),
#  'agency': '0001',
#  'balance': 4813.0,
#  'client': {'address': '188561967',
#             'cpf': '773381619',
#             'id': 25,
#             'name': 'Janet Marshall'},
#  'id_client': 25,
#  'num': 25,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dc0'),
#  'agency': '0001',
#  'balance': 1878.0,
#  'client': {'address': '718696998',
#             'cpf': '478807361',
#             'id': 26,
#             'name': 'Natalie Lopez DVM'},
#  'id_client': 26,
#  'num': 26,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dc1'),
#  'agency': '0001',
#  'balance': 8481.0,
#  'client': {'address': '960649403',
#             'cpf': '250781620',
#             'id': 27,
#             'name': 'Andrew Kennedy'},
#  'id_client': 27,
#  'num': 27,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dc2'),
#  'agency': '0001',
#  'balance': 7986.0,
#  'client': {'address': '450182333',
#             'cpf': '499405086',
#             'id': 28,
#             'name': 'Annette Hart'},
#  'id_client': 28,
#  'num': 28,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e96d0b20ffddd687dc3'),
#  'agency': '0001',
#  'balance': 7608.0,
#  'client': {'address': '703093902',
#             'cpf': '594815024',
#             'id': 29,
#             'name': 'Michael Scott'},
#  'id_client': 29,
#  'num': 29,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dc4'),
#  'agency': '0001',
#  'balance': 8995.0,
#  'client': {'address': '751726274',
#             'cpf': '505033328',
#             'id': 30,
#             'name': 'Jesse Martinez'},
#  'id_client': 30,
#  'num': 30,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dc5'),
#  'agency': '0001',
#  'balance': 2556.0,
#  'client': {'address': '416249660',
#             'cpf': '674442940',
#             'id': 31,
#             'name': 'Dustin Lucas'},
#  'id_client': 31,
#  'num': 31,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dc6'),
#  'agency': '0001',
#  'balance': 2910.0,
#  'client': {'address': '611209245',
#             'cpf': '659893175',
#             'id': 32,
#             'name': 'Heather Evans'},
#  'id_client': 32,
#  'num': 32,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dc7'),
#  'agency': '0001',
#  'balance': 4313.0,
#  'client': {'address': '663173817',
#             'cpf': '953421848',
#             'id': 33,
#             'name': 'Stephen Phillips'},
#  'id_client': 33,
#  'num': 33,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dc8'),
#  'agency': '0001',
#  'balance': 9891.0,
#  'client': {'address': '911364646',
#             'cpf': '405252872',
#             'id': 34,
#             'name': 'Brenda Bailey'},
#  'id_client': 34,
#  'num': 34,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dc9'),
#  'agency': '0001',
#  'balance': 9084.0,
#  'client': {'address': '930499589',
#             'cpf': '646290619',
#             'id': 35,
#             'name': 'Jessica Ford'},
#  'id_client': 35,
#  'num': 35,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dca'),
#  'agency': '0001',
#  'balance': 3884.0,
#  'client': {'address': '732942984',
#             'cpf': '727348162',
#             'id': 36,
#             'name': 'Mark Carpenter'},
#  'id_client': 36,
#  'num': 36,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dcb'),
#  'agency': '0001',
#  'balance': 3188.0,
#  'client': {'address': '648121356',
#             'cpf': '684602836',
#             'id': 37,
#             'name': 'Dillon Baker'},
#  'id_client': 37,
#  'num': 37,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dcc'),
#  'agency': '0001',
#  'balance': 5906.0,
#  'client': {'address': '142479937',
#             'cpf': '414256853',
#             'id': 38,
#             'name': 'Anna Bailey'},
#  'id_client': 38,
#  'num': 38,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dcd'),
#  'agency': '0001',
#  'balance': 4424.0,
#  'client': {'address': '481973877',
#             'cpf': '706269705',
#             'id': 39,
#             'name': 'Alexandria Miller'},
#  'id_client': 39,
#  'num': 39,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dce'),
#  'agency': '0001',
#  'balance': 5009.0,
#  'client': {'address': '561237041',
#             'cpf': '578598452',
#             'id': 40,
#             'name': 'Nancy Garcia'},
#  'id_client': 40,
#  'num': 40,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dcf'),
#  'agency': '0001',
#  'balance': 363.0,
#  'client': {'address': '608168100',
#             'cpf': '314819919',
#             'id': 41,
#             'name': 'Brent Smith'},
#  'id_client': 41,
#  'num': 41,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dd0'),
#  'agency': '0001',
#  'balance': 7105.0,
#  'client': {'address': '464416051',
#             'cpf': '990282317',
#             'id': 42,
#             'name': 'Christine Carter'},
#  'id_client': 42,
#  'num': 42,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dd1'),
#  'agency': '0001',
#  'balance': 7806.0,
#  'client': {'address': '377741042',
#             'cpf': '557476168',
#             'id': 43,
#             'name': 'Tracy Anderson'},
#  'id_client': 43,
#  'num': 43,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dd2'),
#  'agency': '0001',
#  'balance': 7853.0,
#  'client': {'address': '467255936',
#             'cpf': '185534622',
#             'id': 44,
#             'name': 'Anna Blackwell'},
#  'id_client': 44,
#  'num': 44,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dd3'),
#  'agency': '0001',
#  'balance': 8592.0,
#  'client': {'address': '438709303',
#             'cpf': '311447893',
#             'id': 45,
#             'name': 'Christine Johnson'},
#  'id_client': 45,
#  'num': 45,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dd4'),
#  'agency': '0001',
#  'balance': 8151.0,
#  'client': {'address': '189276661',
#             'cpf': '384225333',
#             'id': 46,
#             'name': 'Paula Cooley'},
#  'id_client': 46,
#  'num': 46,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dd5'),
#  'agency': '0001',
#  'balance': 8561.0,
#  'client': {'address': '967434812',
#             'cpf': '267209303',
#             'id': 47,
#             'name': 'Dylan Trujillo'},
#  'id_client': 47,
#  'num': 47,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dd6'),
#  'agency': '0001',
#  'balance': 4969.0,
#  'client': {'address': '973326960',
#             'cpf': '276492078',
#             'id': 48,
#             'name': 'Ruben Owens'},
#  'id_client': 48,
#  'num': 48,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dd7'),
#  'agency': '0001',
#  'balance': 7188.0,
#  'client': {'address': '242653611',
#             'cpf': '776281797',
#             'id': 49,
#             'name': 'Michael Hernandez'},
#  'id_client': 49,
#  'num': 49,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dd8'),
#  'agency': '0001',
#  'balance': 5053.0,
#  'client': {'address': '765950377',
#             'cpf': '899577199',
#             'id': 50,
#             'name': 'Whitney Brown'},
#  'id_client': 50,
#  'num': 50,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dd9'),
#  'agency': '0001',
#  'balance': 1502.0,
#  'client': {'address': '186026889',
#             'cpf': '285324851',
#             'id': 51,
#             'name': 'Christine Chavez'},
#  'id_client': 51,
#  'num': 51,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dda'),
#  'agency': '0001',
#  'balance': 1598.0,
#  'client': {'address': '508323601',
#             'cpf': '553547488',
#             'id': 52,
#             'name': 'Allen Travis'},
#  'id_client': 52,
#  'num': 52,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687ddb'),
#  'agency': '0001',
#  'balance': 5885.0,
#  'client': {'address': '861214944',
#             'cpf': '772372959',
#             'id': 53,
#             'name': 'Lisa Brooks'},
#  'id_client': 53,
#  'num': 53,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687ddc'),
#  'agency': '0001',
#  'balance': 7442.0,
#  'client': {'address': '297407208',
#             'cpf': '954143018',
#             'id': 54,
#             'name': 'Lisa Williams'},
#  'id_client': 54,
#  'num': 54,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687ddd'),
#  'agency': '0001',
#  'balance': 5429.0,
#  'client': {'address': '660239504',
#             'cpf': '106832992',
#             'id': 55,
#             'name': 'Samuel French IV'},
#  'id_client': 55,
#  'num': 55,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687dde'),
#  'agency': '0001',
#  'balance': 6795.0,
#  'client': {'address': '998481224',
#             'cpf': '889011878',
#             'id': 56,
#             'name': 'Sergio Reyes DVM'},
#  'id_client': 56,
#  'num': 56,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687ddf'),
#  'agency': '0001',
#  'balance': 9254.0,
#  'client': {'address': '238373716',
#             'cpf': '678799019',
#             'id': 57,
#             'name': 'Patricia Beltran'},
#  'id_client': 57,
#  'num': 57,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687de0'),
#  'agency': '0001',
#  'balance': 8595.0,
#  'client': {'address': '749647040',
#             'cpf': '340780469',
#             'id': 58,
#             'name': 'Dwayne Quinn'},
#  'id_client': 58,
#  'num': 58,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e97d0b20ffddd687de1'),
#  'agency': '0001',
#  'balance': 5833.0,
#  'client': {'address': '811749465',
#             'cpf': '117614283',
#             'id': 59,
#             'name': 'Lauren Thornton'},
#  'id_client': 59,
#  'num': 59,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687de2'),
#  'agency': '0001',
#  'balance': 9710.0,
#  'client': {'address': '824747065',
#             'cpf': '602049582',
#             'id': 60,
#             'name': 'Christina Rogers'},
#  'id_client': 60,
#  'num': 60,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687de3'),
#  'agency': '0001',
#  'balance': 6876.0,
#  'client': {'address': '694206223',
#             'cpf': '905638704',
#             'id': 61,
#             'name': 'Jerome Martin'},
#  'id_client': 61,
#  'num': 61,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687de4'),
#  'agency': '0001',
#  'balance': 4965.0,
#  'client': {'address': '617786436',
#             'cpf': '869937022',
#             'id': 62,
#             'name': 'Holly Hatfield'},
#  'id_client': 62,
#  'num': 62,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687de5'),
#  'agency': '0001',
#  'balance': 8341.0,
#  'client': {'address': '662386896',
#             'cpf': '503558651',
#             'id': 63,
#             'name': 'Charles Anderson'},
#  'id_client': 63,
#  'num': 63,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687de6'),
#  'agency': '0001',
#  'balance': 6182.0,
#  'client': {'address': '657604801',
#             'cpf': '302789502',
#             'id': 64,
#             'name': 'Sandra Garcia'},
#  'id_client': 64,
#  'num': 64,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687de7'),
#  'agency': '0001',
#  'balance': 3653.0,
#  'client': {'address': '463011469',
#             'cpf': '308381109',
#             'id': 65,
#             'name': 'Sarah Levy'},
#  'id_client': 65,
#  'num': 65,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687de8'),
#  'agency': '0001',
#  'balance': 9061.0,
#  'client': {'address': '390772547',
#             'cpf': '438258120',
#             'id': 66,
#             'name': 'Amber Rogers'},
#  'id_client': 66,
#  'num': 66,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687de9'),
#  'agency': '0001',
#  'balance': 5887.0,
#  'client': {'address': '418964942',
#             'cpf': '814678410',
#             'id': 67,
#             'name': 'James Hunter'},
#  'id_client': 67,
#  'num': 67,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687dea'),
#  'agency': '0001',
#  'balance': 3839.0,
#  'client': {'address': '636407407',
#             'cpf': '645153642',
#             'id': 68,
#             'name': 'Lisa Jenkins'},
#  'id_client': 68,
#  'num': 68,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687deb'),
#  'agency': '0001',
#  'balance': 6830.0,
#  'client': {'address': '357009723',
#             'cpf': '457730126',
#             'id': 69,
#             'name': 'Alexis Bennett'},
#  'id_client': 69,
#  'num': 69,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687dec'),
#  'agency': '0001',
#  'balance': 7659.0,
#  'client': {'address': '267855021',
#             'cpf': '516596339',
#             'id': 70,
#             'name': 'Joshua Larsen'},
#  'id_client': 70,
#  'num': 70,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687ded'),
#  'agency': '0001',
#  'balance': 1502.0,
#  'client': {'address': '857459631',
#             'cpf': '943470969',
#             'id': 71,
#             'name': 'Kyle Maxwell'},
#  'id_client': 71,
#  'num': 71,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687dee'),
#  'agency': '0001',
#  'balance': 5036.0,
#  'client': {'address': '644640853',
#             'cpf': '719684741',
#             'id': 72,
#             'name': 'Angela Ho'},
#  'id_client': 72,
#  'num': 72,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687def'),
#  'agency': '0001',
#  'balance': 6233.0,
#  'client': {'address': '917056917',
#             'cpf': '573504267',
#             'id': 73,
#             'name': 'Heather White'},
#  'id_client': 73,
#  'num': 73,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687df0'),
#  'agency': '0001',
#  'balance': 6096.0,
#  'client': {'address': '284013678',
#             'cpf': '896645557',
#             'id': 74,
#             'name': 'Nicholas Boyer'},
#  'id_client': 74,
#  'num': 74,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687df1'),
#  'agency': '0001',
#  'balance': 593.0,
#  'client': {'address': '863462881',
#             'cpf': '966976309',
#             'id': 75,
#             'name': 'Dale Smith'},
#  'id_client': 75,
#  'num': 75,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687df2'),
#  'agency': '0001',
#  'balance': 8212.0,
#  'client': {'address': '788443783',
#             'cpf': '266495227',
#             'id': 76,
#             'name': 'Jeffrey Atkins'},
#  'id_client': 76,
#  'num': 76,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687df3'),
#  'agency': '0001',
#  'balance': 9750.0,
#  'client': {'address': '714087283',
#             'cpf': '567946173',
#             'id': 77,
#             'name': 'Jessica Pena'},
#  'id_client': 77,
#  'num': 77,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687df4'),
#  'agency': '0001',
#  'balance': 2321.0,
#  'client': {'address': '253060061',
#             'cpf': '448595599',
#             'id': 78,
#             'name': 'Donna Taylor'},
#  'id_client': 78,
#  'num': 78,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687df5'),
#  'agency': '0001',
#  'balance': 4770.0,
#  'client': {'address': '149305764',
#             'cpf': '825430619',
#             'id': 79,
#             'name': 'Richard Evans'},
#  'id_client': 79,
#  'num': 79,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687df6'),
#  'agency': '0001',
#  'balance': 6377.0,
#  'client': {'address': '575209025',
#             'cpf': '732805995',
#             'id': 80,
#             'name': 'Diana Sanders'},
#  'id_client': 80,
#  'num': 80,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687df7'),
#  'agency': '0001',
#  'balance': 5665.0,
#  'client': {'address': '982084780',
#             'cpf': '297892698',
#             'id': 81,
#             'name': 'Robert Mcdonald'},
#  'id_client': 81,
#  'num': 81,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687df8'),
#  'agency': '0001',
#  'balance': 1493.0,
#  'client': {'address': '884769810',
#             'cpf': '366560811',
#             'id': 82,
#             'name': 'Ryan Howard'},
#  'id_client': 82,
#  'num': 82,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687df9'),
#  'agency': '0001',
#  'balance': 4648.0,
#  'client': {'address': '895406445',
#             'cpf': '982320604',
#             'id': 83,
#             'name': 'Jennifer Boone'},
#  'id_client': 83,
#  'num': 83,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687dfa'),
#  'agency': '0001',
#  'balance': 3261.0,
#  'client': {'address': '100249071',
#             'cpf': '565367753',
#             'id': 84,
#             'name': 'Mr. John Phillips'},
#  'id_client': 84,
#  'num': 84,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687dfb'),
#  'agency': '0001',
#  'balance': 9188.0,
#  'client': {'address': '867609036',
#             'cpf': '440130378',
#             'id': 85,
#             'name': 'Alyssa Armstrong'},
#  'id_client': 85,
#  'num': 85,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687dfc'),
#  'agency': '0001',
#  'balance': 8879.0,
#  'client': {'address': '418882478',
#             'cpf': '824638082',
#             'id': 86,
#             'name': 'Misty Whitaker'},
#  'id_client': 86,
#  'num': 86,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687dfd'),
#  'agency': '0001',
#  'balance': 8410.0,
#  'client': {'address': '685602083',
#             'cpf': '169096388',
#             'id': 87,
#             'name': 'Melissa Powell'},
#  'id_client': 87,
#  'num': 87,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687dfe'),
#  'agency': '0001',
#  'balance': 7462.0,
#  'client': {'address': '207687882',
#             'cpf': '302128995',
#             'id': 88,
#             'name': 'William Brown'},
#  'id_client': 88,
#  'num': 88,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e98d0b20ffddd687dff'),
#  'agency': '0001',
#  'balance': 6492.0,
#  'client': {'address': '590501102',
#             'cpf': '456505470',
#             'id': 89,
#             'name': 'Donald Griffin'},
#  'id_client': 89,
#  'num': 89,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e00'),
#  'agency': '0001',
#  'balance': 8957.0,
#  'client': {'address': '580636796',
#             'cpf': '519375965',
#             'id': 90,
#             'name': 'Jonathan Kramer'},
#  'id_client': 90,
#  'num': 90,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e01'),
#  'agency': '0001',
#  'balance': 5231.0,
#  'client': {'address': '731651683',
#             'cpf': '188439748',
#             'id': 91,
#             'name': 'Brittany Lucas'},
#  'id_client': 91,
#  'num': 91,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e02'),
#  'agency': '0001',
#  'balance': 9938.0,
#  'client': {'address': '145923867',
#             'cpf': '151004776',
#             'id': 92,
#             'name': 'Joshua Shepard'},
#  'id_client': 92,
#  'num': 92,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e03'),
#  'agency': '0001',
#  'balance': 8930.0,
#  'client': {'address': '605193547',
#             'cpf': '688590099',
#             'id': 93,
#             'name': 'Jeff Mcgrath'},
#  'id_client': 93,
#  'num': 93,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e04'),
#  'agency': '0001',
#  'balance': 5577.0,
#  'client': {'address': '404045788',
#             'cpf': '897629137',
#             'id': 94,
#             'name': 'Audrey Choi'},
#  'id_client': 94,
#  'num': 94,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e05'),
#  'agency': '0001',
#  'balance': 2090.0,
#  'client': {'address': '908907651',
#             'cpf': '923423931',
#             'id': 95,
#             'name': 'Eugene Johnson'},
#  'id_client': 95,
#  'num': 95,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e06'),
#  'agency': '0001',
#  'balance': 1955.0,
#  'client': {'address': '927652664',
#             'cpf': '938004343',
#             'id': 96,
#             'name': 'Casey Ward'},
#  'id_client': 96,
#  'num': 96,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e07'),
#  'agency': '0001',
#  'balance': 8524.0,
#  'client': {'address': '860108228',
#             'cpf': '715824180',
#             'id': 97,
#             'name': 'Diane Scott'},
#  'id_client': 97,
#  'num': 97,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e08'),
#  'agency': '0001',
#  'balance': 3699.0,
#  'client': {'address': '939465088',
#             'cpf': '363708062',
#             'id': 98,
#             'name': 'Kimberly Martinez'},
#  'id_client': 98,
#  'num': 98,
#  'type': 'CS'}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e09'),
#  'agency': '0001',
#  'balance': 9390.0,
#  'client': {'address': '765673551',
#             'cpf': '717016336',
#             'id': 99,
#             'name': 'Laura Robinson'},
#  'id_client': 99,
#  'num': 99,
#  'type': 'CC'}
# {'_id': ObjectId('65ad9e99d0b20ffddd687e0a'),
#  'agency': '0001',
#  'balance': 7336.0,
#  'client': {'address': '123843260',
#             'cpf': '889704153',
#             'id': 100,
#             'name': 'Dana Norris'},
#  'id_client': 100,
#  'num': 100,
#  'type': 'CS'}
